# %% [markdown]
# Topic 5 DQ1

# %% [markdown]
# Explain the difference between correlation and causation. Why is it important to understand the distinction between the two when interpreting statistical results? Provide at least two examples of a correlation that does not necessarily imply causation. How can hypothesis testing be used to determine whether a correlation is statistically significant and can be used to make causal inferences?

# %%
#importing libraries that are needed
#set up
import  numpy as np
import pandas as pd
import scipy.stats as stats
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# /var/folders/x1/3h80s1d10bx2rgftf2cxmc980000gn/T/ipykernel_75596/3763607885.py:4: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
#reading csv file and printin it out
posture_personality_trait = pd.read_csv("Myers Briggs Table_S1.csv")
posture_personality_trait.head()
# Out:
#    S No  AGE  HEIGHT  WEIGHT     SEX ACTIVITY LEVEL  PAIN 1  PAIN 2  PAIN 3  \
# 0     1   53      62     125  Female            Low     0.0     0.0     0.0
# 1     2   52      69     157    Male           High     7.0     8.0     5.0
# 2     3   30      69     200    Male           High     0.0     0.0     0.0
# 3     4   51      66     175    Male       Moderate     9.5     9.5     9.5
# 4     5   45      63     199  Female       Moderate     4.0     5.0     2.0
#
#    PAIN 4  MBTI   E   I   S   N   T   F   J   P POSTURE
# 0     0.0  ESFJ  18   3  17   9   9  13  18   4       A
# 1     3.0  ISTJ   6  15  14  12  21   3  13   9       B
# 2     0.0  ESTJ  15   6  16  10  15   9  12  10       A
# 3     1.5  ISTJ   6  15  21   5  13  11  19   3       D
# 4     2.0  ENFJ  14   7  20   6   9  15  16   6       A

# %%
#creating a scatter plot with wieght vs height with differnt colors corresponding to the posture 
sns.scatterplot(data = posture_personality_trait, x = 'WEIGHT', y = 'HEIGHT',  hue  = 'POSTURE')
# Out:
# <Axes: xlabel='WEIGHT', ylabel='HEIGHT'>

# %%
stats.pearsonr(posture_personality_trait['WEIGHT'],posture_personality_trait['HEIGHT'])
# Out:
# PearsonRResult(statistic=0.5508712009112281, pvalue=5.024692326645194e-09)

# %%
#creating a scatter plot with age vs weight with differnt colors corresponding to the posture 
sns.scatterplot(data = posture_personality_trait, x = 'AGE', y = 'WEIGHT',  hue  = 'POSTURE')
# Out:
# <Axes: xlabel='AGE', ylabel='WEIGHT'>

# %%
stats.pearsonr(posture_personality_trait['AGE'],posture_personality_trait['WEIGHT'])
# Out:
# PearsonRResult(statistic=0.2727578539381731, pvalue=0.006872024273663563)

# %%
#creating a scatter plot with age vs height with differnt colors corresponding to the posture 
sns.scatterplot(data = posture_personality_trait, x = 'AGE', y = 'HEIGHT',  hue  = 'POSTURE')
# Out:
# <Axes: xlabel='AGE', ylabel='HEIGHT'>

# %%
stats.pearsonr(posture_personality_trait['AGE'],posture_personality_trait['HEIGHT'])
# Out:
# PearsonRResult(statistic=-0.02903205377757426, pvalue=0.7777247236459004)
